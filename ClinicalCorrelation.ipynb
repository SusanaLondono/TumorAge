# %%
import pandas as pd

# %%
data = pd.read_csv('BRCA-TP.samplefeatures.txt', sep='\t')

# %%
data = data[['tcga_participant_barcode', 'CLI_years_to_birth', 'CLI_vital_status', 'CLI_days_to_death',
                     'CLI_days_to_last_followup', 'CLI_tumor_tissue_site' ,
                     'CLI_gender', 'CLI_date_of_initial_pathologic_diagnosis', 'CLI_days_to_last_known_alive',
                     'CLI_radiation_therapy','CLI_race', 'CLI_ethnicity', 'rate_non', 'rate_sil']].copy()
ps_cli = data.tcga_participant_barcode.drop_duplicates()
ps_cli= ps_cli.sort_values()

# %%
ps_cli = ps_cli.tolist()

# %%
mafData = pd.read_csv('medidasxpaciente.txt', sep='\t')
#mafData.Patient_Id

# %%
ps_med = []
for patient in mafData.Patient_Id:
    patient = patient[0:12]
    ps_med.append(patient)
#ps_med

# %%
print (set(ps_med).union(data.tcga_participant_barcode)  - set(ps_med).intersection(data.tcga_participant_barcode))
# Out:
# {nan, 'TCGA-AR-A0TR', 'TCGA-A1-A0SO', 'TCGA-AR-A0TP', 'TCGA-3C-AALI', 'TCGA-LL-A9Q3', 'TCGA-Z7-A8R5', 'TCGA-LL-A6FQ', 'TCGA-UL-AAZ6', 'TCGA-E2-A106', 'TCGA-LL-A7T0', 'TCGA-V7-A7HQ', 'TCGA-3C-AALK', 'TCGA-AC-A62V', 'TCGA-A7-A6VX', 'TCGA-E9-A6HE', 'TCGA-AR-A0U4', 'TCGA-LL-A6FR', 'TCGA-S3-AA15', 'TCGA-BH-A0B2', 'TCGA-E9-A1N6', 'TCGA-OL-A6VR', 'TCGA-AC-A7VC', 'TCGA-EW-A1OW', 'TCGA-S3-AA10', 'TCGA-Z7-A8R6', 'TCGA-PL-A8LV', 'TCGA-EW-A6SA', 'TCGA-EW-A1PF', 'TCGA-LD-A66U', 'TCGA-A2-A0CY', 'TCGA-AR-A0TT', 'TCGA-OL-A66O', 'TCGA-5T-A9QA', 'TCGA-EW-A6SC', 'TCGA-D8-A1XD', 'TCGA-A7-A6VY', 'TCGA-LD-A9QF', 'TCGA-LD-A7W6', 'TCGA-E2-A9RU', 'TCGA-OL-A66L', 'TCGA-AQ-A7U7', 'TCGA-S3-AA14', 'TCGA-B6-A0RM', 'all_p', 'TCGA-AC-A6IW', 'TCGA-WT-AB41', 'TCGA-AC-A8OP', 'TCGA-AO-A0JG', 'TCGA-OL-A66N', 'TCGA-OL-A66P', 'TCGA-A8-A07S', 'TCGA-OL-A6VQ', 'TCGA-AO-A12C', 'TCGA-BH-AB28', 'TCGA-BH-A8G0', 'all_q', 'TCGA-EW-A424', 'TCGA-EW-A6SD', 'TCGA-AR-A0TV', 'TCGA-LL-A8F5', 'TCGA-A7-A6VW', 'TCGA-LL-A73Z', 'TCGA-S3-AA0Z'
# ...

# %%
pats = ss.intersection(fs)
#pats

# %%
print(set(pats).union(ps_med) - set(pats).intersection(ps_med))
# Out:
# set()

# %%
#data.tcga_participant_barcode

# %%
#df = df[df.line_race != 0]
difs =  ['TCGA-AR-A0TR', 'TCGA-A1-A0SO', 'TCGA-AR-A0TP', 'TCGA-3C-AALI', 'TCGA-LL-A9Q3', 'TCGA-Z7-A8R5', 
           'TCGA-LL-A6FQ', 'TCGA-UL-AAZ6', 'TCGA-E2-A106', 'TCGA-LL-A7T0', 'TCGA-V7-A7HQ', 'TCGA-3C-AALK', 
           'TCGA-AC-A62V', 'TCGA-A7-A6VX', 'TCGA-E9-A6HE', 'TCGA-AR-A0U4', 'TCGA-LL-A6FR', 'TCGA-S3-AA15', 
           'TCGA-BH-A0B2', 'TCGA-E9-A1N6', 'TCGA-OL-A6VR', 'TCGA-AC-A7VC', 'TCGA-EW-A1OW', 'TCGA-S3-AA10', 
           'TCGA-Z7-A8R6', 'TCGA-PL-A8LV', 'TCGA-EW-A6SA', 'TCGA-EW-A1PF', 'TCGA-LD-A66U', 'TCGA-A2-A0CY', 
           'TCGA-AR-A0TT', 'TCGA-OL-A66O', 'TCGA-5T-A9QA', 'TCGA-EW-A6SC', 'TCGA-D8-A1XD', 'TCGA-A7-A6VY', 
           'TCGA-LD-A9QF', 'TCGA-LD-A7W6', 'TCGA-E2-A9RU', 'TCGA-OL-A66L', 'TCGA-AQ-A7U7', 'TCGA-S3-AA14', 
           'TCGA-B6-A0RM', 'all_p', 'TCGA-AC-A6IW', 'TCGA-WT-AB41', 'TCGA-AC-A8OP', 'TCGA-AO-A0JG', 
           'TCGA-OL-A66N', 'TCGA-OL-A66P', 'TCGA-A8-A07S', 'TCGA-OL-A6VQ', 'TCGA-AO-A12C', 'TCGA-BH-AB28', 
           'TCGA-BH-A8G0', 'all_q', 'TCGA-EW-A424', 'TCGA-EW-A6SD', 'TCGA-AR-A0TV', 'TCGA-LL-A8F5', 
           'TCGA-A7-A6VW', 'TCGA-LL-A73Z', 'TCGA-S3-AA0Z', 'TCGA-AR-A0TQ', 'TCGA-EW-A6SB', 'TCGA-PL-A8LX', 
           'TCGA-AC-A6IV', 'TCGA-B6-A0RS', 'TCGA-S3-A6ZH', 'TCGA-LD-A74U', 'TCGA-C8-A8HR', 'TCGA-WT-AB44', 
           'TCGA-D8-A73U', 'TCGA-3C-AALJ', 'TCGA-5L-AAT1', 'TCGA-S3-AA12', 'TCGA-AC-A8OR', 'TCGA-PL-A8LZ', 
           'TCGA-D8-A73W', 'TCGA-3C-AAAU', 'TCGA-LL-A740', 'TCGA-AR-A0TW', 'TCGA-AC-A8OS', 'TCGA-LL-A7SZ', 
           'TCGA-E2-A576', 'TCGA-AC-A8OQ', 'TCGA-A7-A6VV', 'TCGA-S3-A6ZG', 'TCGA-LL-A6FP', 'TCGA-OL-A6VO', 
           'TCGA-BH-A8FZ', 'TCGA-XX-A899', 'TCGA-EW-A6S9', 'TCGA-D8-A73X', 'TCGA-XX-A89A', 'TCGA-4H-AAAK', 
           'TCGA-BH-A6R9', 'TCGA-PL-A8LY', 'TCGA-B6-A0RL', 'TCGA-BH-A1FB', 'TCGA-5L-AAT0', 'TCGA-S3-AA11', 
           'TCGA-BH-A6R8', 'TCGA-OL-A97C', 'TCGA-AC-A6IX', 'TCGA-C8-A8HP', 'TCGA-AC-A7VB', 'TCGA-AO-A1KQ',
           'TCGA-AC-A6NO', 'TCGA-LD-A7W5', 'TCGA-AC-A3QQ', 'TCGA-LL-A442', 'TCGA-C8-A9FZ', 'TCGA-E2-A572',
           'TCGA-UU-A93S', 'TCGA-LL-A73Y', 'TCGA-S3-A6ZF', 'TCGA-W8-A86G', 'TCGA-BH-A8FY', 'TCGA-AR-A0TZ',
           'TCGA-AC-A4ZE', 'TCGA-C8-A8HQ', 'TCGA-S3-AA17']
for d in difs:
    Ndata = data[data.tcga_participant_barcode != d]
    
Ndata.sort_values(by='tcga_participant_barcode')
# Out:
#      tcga_participant_barcode  CLI_years_to_birth  CLI_vital_status  \
# 0                TCGA-3C-AAAU                55.0               0.0
# 1                TCGA-3C-AALI                50.0               0.0
# 2                TCGA-3C-AALJ                62.0               0.0
# 3                TCGA-3C-AALK                52.0               0.0
# 4                TCGA-4H-AAAK                50.0               0.0
# 5                TCGA-5L-AAT0                42.0               0.0
# 6                TCGA-5L-AAT1                63.0               0.0
# 7                TCGA-5T-A9QA                52.0               0.0
# 8                TCGA-A1-A0SB                70.0               0.0
# 9                TCGA-A1-A0SD                59.0               0.0
# 10               TCGA-A1-A0SE                56.0               0.0
# 11               TCGA-A1-A0SF                54.0               0.0
# 12               TCGA-A1-A0SG                61.0               0.0
# ...
